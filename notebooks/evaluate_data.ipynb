# %%
import torch
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

for file in os.listdir('pipeline/1_dm'):
    df = pd.concat([df, pd.read_csv(f'pipeline/1_dm/{file}')])


# df -= df.mean()
# df /= df.std()**2

sns.kdeplot(data=df)
plt.xlim(-20, 20)
# Out:
# (-20.0, 20.0)
